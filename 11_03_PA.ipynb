# %% [markdown]
# <a href="https://colab.research.google.com/github/miguelcorreiaassis10-gif/IW-Etec/blob/main/11_03_PA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#entrada
comprimento = float(input("qual o comprimento?"))
altura = float (input("qual a altura?"))
#processamento
area = comprimento * altura
#saida
print(f"total da area : {area}")
# Out:
# qual o comprimento?100
# qual a altura?100
# total da area : 10000.0

# %%
#escrever um programa que ele calcule ele mesmo

#entrada

numero = int (input("digite um numero:"))

#processamento

dobro = numero * 2
#saida
print(f"o dobro de {numero} é igual a {dobro}")
# Out:
# digite um numero:9
# o dobro de 9 é igual a 18

# %%
# UM  cadastro de usuario

#entrada
nome = str (input("qual seu nome?"))
idade = int (input("qual sua idade?"))

#processamento : armazenar dados

#saida : mostrar mensagem
print(f"boas vindas {nome} seja bem vindo!")
print(f"cadastro : nome :{nome}, idade {idade}")
# Out:
# qual seu nome?aura
# qual sua idade?67
# boas vindas aura seja bem vindo!
# cadastro : nome :aura, idade 67

# %%
# escreva o triplo de um numero
#entrada
num = float (input("digite um numero"))
#processamento
tri = num * 3
#saida
print(f"o triplo de {num} é {tri}")
# Out:
# digite um numero10
# o triplo de 10.0 é 30.0

# %% [markdown]
# esrever um codigo que mostre a idade e uma mensagem de quando ele nasceu

# %%
name = str (input("qual seu nome"))
idade = int (input("qual sua idade?"))

ano = 2026 - idade

print(f"seu nome é {name} nasceu em {ano}")
# Out:
# qual seu nome1000
# qual sua idade?1000
# seu nome é 1000 nasceu em 1026

# %% [markdown]
# escrever conversao
# formula F = (c x 9/5) + 32

# %%
C = float (input("qual a temperatura atual?"))
F = C * 9 / 5 + 32
print(f"hoje ests {C} graus celsius e {F} faherenheit")
# Out:
# qual a temperatura atual?19.45
# hoje ests 19.45 graus celsius e 67.00999999999999 faherenheit

# %% [markdown]
# adicionais

# %%
name = str (input("qual seu nome"))
senha = int (input("qual sua senha?"))
print("cadasro feito")
# Out:
# qual seu nomeai
# qual sua senha?111
# cadasro feito

# %%
nam = str (input("digite seu nome"))
senh = int (input("digite sua senha"))
if senh == senha and nam == name:
    print("pode entrar")
else:
  print("acesso negado")
# Out:
# digite seu nomeai
# digite sua senha111
# pode entrar
