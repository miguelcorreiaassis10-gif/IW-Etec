# %% [markdown]
# <a href="https://colab.research.google.com/github/miguelcorreiaassis10-gif/IW-Etec/blob/main/escola_2_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello word")
# Out:
# hello word

# %% [markdown]
# ---
#
#
# # **Entrada**
#
# 1.   ler lado1
# 2.   ler lado2
#
#
# ---
#
#
#
# # **Processamento**
#
#
# *   area = lado1 * lado2
#
#
#
# ---
#
# # **saida**
#
#
#
#
# *   imprimir area
#
#
#
#
#
# ---

# %%
# calculo da area
# entrada
lado1 = 3.0
lado2 = 4.5
# processamento
area = lado1 * lado2
# saida
print(area)
# Out:
# 13.5

# %%
lado1 = int (input("qual o primeiro lado?"))
lado2 = int (input("qual o segundo lado?"))
area = lado1 * lado2
print(f"total da area : {area}")
# Out:
# qual o primeiro lado?10
# qual o segundo lado?10
# total da area : 100

# %%
#tipos de numeros
idade = 14 #int
altura =1.91 #float
numero_complexo [- 2 + 3] #complex
 # Tipo de Texto
 nome = "miguel" #str

 #tipo boleano
 esta_chovendo = False #bool

# %%
nota1 = float (input("sua primeira nota"))
nota2 = float (input("sua segunda nota"))
nota3 = float (input("sua terceira nota"))
nota4 = float (input("sua quarta nota"))
notaF = nota1 + nota2 + nota3 + nota4
notaB = notaF / 4
print(f"sua nota bimestral é :{notaB}")
if notaB >= 7.0:
  print("aprovado")
else:
  print("reprovado")
# Out:
# sua primeira nota10
# sua segunda nota10
# sua terceira nota6.67
# sua quarta nota4
# sua nota bimestral é :7.6675
# aprovado
