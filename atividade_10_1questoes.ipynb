# %% [markdown]
# <a href="https://colab.research.google.com/github/miguelcorreiaassis10-gif/IW-Etec/blob/main/atividade_10_1questoes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## ***listas***

# %%
frutas = ["maçã", "banana", "laranja", "morango"]
print(frutas)
# Out:
# ['maçã', 'banana', 'laranja', 'morango']

# %%
nomes = ["Rebeca", "Guilherme", "Melissa", "Kyara"]
print(nomes[0])
print(nomes[1])
print(nomes[-1])
# Out:
# Rebeca
# Guilherme
# Kyara

# %%
cores = ["vermelho", "azul", "verde"]
cores[1] = "amarelo"
print(cores)
# Out:
# ['vermelho', 'amarelo', 'verde']

# %%
alunos = ["Nicolas", "Wendel", "Pyetra"]
alunos.append("Petros")
print(alunos)
# Out:
# ['Nicolas', 'Wendel', 'Pyetra', 'Petros']

# %%
animais = ["cachorro", "gato", "coelho", "passarinho"]
animais.remove("coelho")
print(animais)
# Out:
# ['cachorro', 'gato', 'passarinho']

# %% [markdown]
# # ***Tuplas***

# %%
meses = ("Janeiro", "Fevereiro", "Março", "Abril")
print(meses)
# Out:
# ('Janeiro', 'Fevereiro', 'Março', 'Abril')

# %%
numeros = (10, 20, 30, 40, 50)
print(numeros[0])
print(numeros[2])
print(numeros[-1])
# Out:
# 10
# 30
# 50

# %%
aluno = ("Lucas", 20, "Engenharia")
print(aluno[0])
print(aluno[1])
print(aluno[2])
# Out:
# Lucas
# 20
# Engenharia

# %%
cores = ("vermelho", "azul", "verde")
cores[1] = "amarelo"
#tupla não se altera
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_749/2472117528.py in <cell line: 0>()
#       1 cores = ("vermelho", "azul", "verde")
# ----> 2 cores[1] = "amarelo"
#
# TypeError: 'tuple' object does not support item assignment

# %%
numeros = (2, 4, 2, 6, 2, 8, 10)
quantidade = numeros.count(2)
print(quantidade)
# Out:
# 3
