# %% [markdown]
# <a href="https://colab.research.google.com/github/miguelcorreiaassis10-gif/IW-Etec/blob/main/exercicios_primeira_aula_leticia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome = str(input("digite seu nome "))
idade = int(input("digite sua idade "))
altura = float(input("digite sua altura "))
nota = float(input("digite sua nota "))
cidade = str(input("digite o nome da sua cidade "))
print(type(nome))
print(nome)
print(type(idade))
print(idade)
print(type(altura))
print(altura)
print(type(nota))
print(nota)
print(type(cidade))
print(cidade)
print(nome,idade,altura,nota,cidade)
# Out:
# digite seu nomeronaldo
# digite sua idade67
# digite sua altura1.67
# digite sua nota0.67
# digite o nome da sua cidadesix seven da silva
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'float'>
# <class 'str'>

# %%
n1 = 7.5
n2 = 8.0
n3 = 6.5
conta = n1 + n2 + n3
nf = conta / 3
print(nf)
# Out:
# 7.333333333333333

# %%
#Exercício 3 – Conversões
Faça as conversões e mostre o resultado:
Python
texto1 = "20"
texto2 = "3.5"
numero = 8
a) Transforme texto1 em inteiro e some com 10 b) Transforme texto2 em real e
multiplique por 2 c) Transforme número em texto e junte com a palavra "anos"

# %%
t1 = "20"
t2 = "3.5"
n = 8
n1 = int(t1)
n2 = float(t2)
t3 = str(n)
print(n1 + 10)
print(n2 * 2)
print(f' {t3} anos')
# Out:
# 30
# 7.0
#  8 anos

# %%
idade = 16
nota = 8.5
preco = 45.0
idade >= 18
nota > 7
preco <= 50
idade == 16
nota != 10
print(idade >= 18)
print(nota > 7)
print(preco <= 50)
print(idade == 16)
print(nota != 10)
# Out:
# False
# True
# True
# True
# True

# %%
produto = 80
desconto = 80/10
vf = produto - desconto
print(produto)
print(desconto)
print(vf)
print(vf < 75)
# Out:
# 80
# 8.0
# 72.0
# True

# %%
nome = str(input("qual seu nome? "))
n1 = float(input(" qual sua nota do Primeiro bimestre? "))
n2 = float(input(" qual sua nota do Segundo bimestre? "))
nb = n1 + n2
nf = nb / 2
print(f' o aluno {nome} tirou {nf}')
# Out:
# qual seu nome? Thung
#  qual sua nota do Primeiro bimestre? 67
#  qual sua nota do Segundo bimestre? 67
#  o aluno Thung tirou 67.0
