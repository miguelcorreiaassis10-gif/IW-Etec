# %% [markdown]
# <a href="https://colab.research.google.com/github/miguelcorreiaassis10-gif/IW-Etec/blob/main/27_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#jogo menu inteligente
#crie um sistema que funcione ate o usuario desejar sair
# menu
# par / impar
# positivo negativo
# maior
# sair
opc = int(input("escolha uma opção de jogo "))
opc1 = 1
opc2 = 2
opc3 = 3
try:
  while opc != 4:
    if opc == 1:
      num = int(input("digite um numero "))
      if num % 2 == 0:
        print("par ")
      else:
        print("impar")
    elif opc == 2:
      num = int(input("digite um numero "))
      if num > 0:
        print("positivo ")
      elif num < 0:
        print("negativo ")
      else:
        print("nulo ")
      break
    elif opc == 3:
      print("sair ")
      break
    else:
      print("digite uma opção valida ")
except:
    print("digite uma opção valida ")
# Out:
# escolha uma opção de jogo3
# sair

# %%
# Urna Eletrônica

# Criar um programa de votação com 3 candidatos

# Votar candidato A
# Votar candidato B
# Votar candidato C
# Votar Branco
# Votar Nulo
# Encerrar votação

# O sistema deve repetir até encerrar a votação
# Contar votos de cada candidato
# Contar votos brancos e nulos
# Ao encerrar, mostrar:

# Total de Votos
# Total de votos por candidato
# Total votos brancos
# Total votos nulos
# Vencedor da eleição

print("bem vindo")
ca = 0
cb = 0
cc = 0
branco = 0
nulo = 0
ab = 0
try:
  while  ab != 10:
    voto = str(input(" digite o nome do seu candidato "))
    if voto == "a":
      print("voto computado")
      ca = ca + 1
      ab = ab + 1
    elif voto == "b":
          print("voto computado")
          cb = cb + 1
    elif voto == "c":
          print("voto computado")
          cc = cc + 1
    elif voto == "branco":
          print("voto computado")
          branco = branco + 1
    elif voto == "nulo":
          print("voto computado")
          nulo = nulo + 1
    else :
          print("encerrando")
          break
    if ab == 10:
      print("total de votos", ab)
      print("total de votos do candidato a", ca)
      print("total de votos do candidato b", cb)
      print("total de votos do candidato c", cc)
      print("total de votos brancos", branco)
      print("total de votos nulos", nulo)
      if ca > cb and ca > cc:
          print("o vencedor é o candidato a")
      elif cb > ca and cb > cc:
          print("o vencedor é o candidato b")
      else:
          print("o vencedor é o candidato c")
except:
      print("coloque um nome elegivel")
# Out:
# bem vindo
#  digite o nome do seu candidato a
# voto computado
#  digite o nome do seu candidato a
# voto computado
#  digite o nome do seu candidato a
# voto computado
#  digite o nome do seu candidato a
# voto computado
#  digite o nome do seu candidato a
# voto computado
#  digite o nome do seu candidato a
# voto computado
#  digite o nome do seu candidato a
# voto computado
#  digite o nome do seu candidato a
# voto computado
#  digite o nome do seu candidato a
# voto computado
#  digite o nome do seu candidato a
# voto computado
# total de votos 1
# total de votos do candidato a 10
# total de votos do candidato b 0
# total de votos do candidato c 0
# total de votos brancos 0
# total de votos nulos 0
# o vencedor é o candidato a

# %% [markdown]
# ///////////////////////////////////////////////////////////////////
